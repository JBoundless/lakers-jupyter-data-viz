# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df = pd.read_csv("/Users/jordanpagkalinawan/Desktop/NBA DV PROJECT/LAKER LEADERS/201314LakersRoster.csv")
playerName = df[df.Player == 'Player']
pointsPerGame = df[df.PTS == 'PTS']
reboundsPerGame = df[df.REB == 'REB']
assistsPerGame = df[df.AST == 'AST']
stealsPerGame = df[df.STL == 'STL']
blocksPerGame = df[df.BLK == 'BLK']
turnoversPerGame = df[df.TOV == 'TOV']
plt.title("2013-14 Lakers Points Per Game")
plt.bar(df.Player, df.PTS, color="gold")
plt.xticks(rotation = 'vertical')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df = pd.read_csv("/Users/jordanpagkalinawan/Desktop/NBA DV PROJECT/LAKER LEADERS/201314LakersRoster.csv")
playerName = df[df.Player == 'Player']
pointsPerGame = df[df.PTS == 'PTS']
reboundsPerGame = df[df.REB == 'REB']
assistsPerGame = df[df.AST == 'AST']
stealsPerGame = df[df.STL == 'STL']
blocksPerGame = df[df.BLK == 'BLK']
turnoversPerGame = df[df.TOV == 'TOV']
plt.title("2013-14 Lakers Rebounds Per Game")
plt.bar(df.Player, df.REB, color="gold")
plt.xticks(rotation = 'vertical')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df = pd.read_csv("/Users/jordanpagkalinawan/Desktop/NBA DV PROJECT/LAKER LEADERS/201314LakersRoster.csv")
playerName = df[df.Player == 'Player']
pointsPerGame = df[df.PTS == 'PTS']
reboundsPerGame = df[df.REB == 'REB']
assistsPerGame = df[df.AST == 'AST']
stealsPerGame = df[df.STL == 'STL']
blocksPerGame = df[df.BLK == 'BLK']
turnoversPerGame = df[df.TOV == 'TOV']
plt.title("2013-14 Lakers Assists Per Game")
plt.bar(df.Player, df.AST, color="gold")
plt.xticks(rotation = 'vertical')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df = pd.read_csv("/Users/jordanpagkalinawan/Desktop/NBA DV PROJECT/LAKER LEADERS/201314LakersRoster.csv")
playerName = df[df.Player == 'Player']
pointsPerGame = df[df.PTS == 'PTS']
reboundsPerGame = df[df.REB == 'REB']
assistsPerGame = df[df.AST == 'AST']
stealsPerGame = df[df.STL == 'STL']
blocksPerGame = df[df.BLK == 'BLK']
turnoversPerGame = df[df.TOV == 'TOV']
plt.title("2013-14 Lakers Steals Per Game")
plt.bar(df.Player, df.STL, color="gold")
plt.xticks(rotation = 'vertical')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df = pd.read_csv("/Users/jordanpagkalinawan/Desktop/NBA DV PROJECT/LAKER LEADERS/201314LakersRoster.csv")
playerName = df[df.Player == 'Player']
pointsPerGame = df[df.PTS == 'PTS']
reboundsPerGame = df[df.REB == 'REB']
assistsPerGame = df[df.AST == 'AST']
stealsPerGame = df[df.STL == 'STL']
blocksPerGame = df[df.BLK == 'BLK']
turnoversPerGame = df[df.TOV == 'TOV']
plt.title("2013-14 Lakers Blocks Per Game")
plt.bar(df.Player, df.BLK, color="gold")
plt.xticks(rotation = 'vertical')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df = pd.read_csv("/Users/jordanpagkalinawan/Desktop/NBA DV PROJECT/LAKER LEADERS/201314LakersRoster.csv")
playerName = df[df.Player == 'Player']
pointsPerGame = df[df.PTS == 'PTS']
reboundsPerGame = df[df.REB == 'REB']
assistsPerGame = df[df.AST == 'AST']
stealsPerGame = df[df.STL == 'STL']
blocksPerGame = df[df.BLK == 'BLK']
turnoversPerGame = df[df.TOV == 'TOV']
plt.title("2013-14 Lakers Turnovers Per Game")
plt.bar(df.Player, df.TOV, color="gold")
plt.xticks(rotation = 'vertical')
plt.show()
