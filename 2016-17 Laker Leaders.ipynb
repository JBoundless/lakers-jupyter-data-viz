# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df = pd.read_csv("/Users/jordanpagkalinawan/Desktop/NBA DV PROJECT/LAKER LEADERS/201617LakersRoster.csv")
playerName = df[df.Player == 'Player']
pointsPerGame = df[df.PTS == 'PTS']
reboundsPerGame = df[df.REB == 'REB']
assistsPerGame = df[df.AST == 'AST']
stealsPerGame = df[df.STL == 'STL']
blocksPerGame = df[df.BLK == 'BLK']
turnoversPerGame = df[df.TOV == 'TOV']
plt.title("2016-17 Lakers Points Per Game")
plt.bar(df.Player, df.PTS)
plt.xticks(rotation = 'vertical')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df = pd.read_csv("/Users/jordanpagkalinawan/Desktop/NBA DV PROJECT/LAKER LEADERS/201617LakersRoster.csv")
playerName = df[df.Player == 'Player']
pointsPerGame = df[df.PTS == 'PTS']
reboundsPerGame = df[df.REB == 'REB']
assistsPerGame = df[df.AST == 'AST']
stealsPerGame = df[df.STL == 'STL']
blocksPerGame = df[df.BLK == 'BLK']
turnoversPerGame = df[df.TOV == 'TOV']
plt.title("2016-17 Lakers Rebounds Per Game")
plt.bar(df.Player, df.REB)
plt.xticks(rotation = 'vertical')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df = pd.read_csv("/Users/jordanpagkalinawan/Desktop/NBA DV PROJECT/LAKER LEADERS/201617LakersRoster.csv")
playerName = df[df.Player == 'Player']
pointsPerGame = df[df.PTS == 'PTS']
reboundsPerGame = df[df.REB == 'REB']
assistsPerGame = df[df.AST == 'AST']
stealsPerGame = df[df.STL == 'STL']
blocksPerGame = df[df.BLK == 'BLK']
turnoversPerGame = df[df.TOV == 'TOV']
plt.title("2016-17 Lakers Assists Per Game")
plt.bar(df.Player, df.AST)
plt.xticks(rotation = 'vertical')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df = pd.read_csv("/Users/jordanpagkalinawan/Desktop/NBA DV PROJECT/LAKER LEADERS/201617LakersRoster.csv")
playerName = df[df.Player == 'Player']
pointsPerGame = df[df.PTS == 'PTS']
reboundsPerGame = df[df.REB == 'REB']
assistsPerGame = df[df.AST == 'AST']
stealsPerGame = df[df.STL == 'STL']
blocksPerGame = df[df.BLK == 'BLK']
turnoversPerGame = df[df.TOV == 'TOV']
plt.title("2016-17 Lakers Steals Per Game")
plt.bar(df.Player, df.STL)
plt.xticks(rotation = 'vertical')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df = pd.read_csv("/Users/jordanpagkalinawan/Desktop/NBA DV PROJECT/LAKER LEADERS/201617LakersRoster.csv")
playerName = df[df.Player == 'Player']
pointsPerGame = df[df.PTS == 'PTS']
reboundsPerGame = df[df.REB == 'REB']
assistsPerGame = df[df.AST == 'AST']
stealsPerGame = df[df.STL == 'STL']
blocksPerGame = df[df.BLK == 'BLK']
turnoversPerGame = df[df.TOV == 'TOV']
plt.title("2016-17 Lakers Blocks Per Game")
plt.bar(df.Player, df.BLK)
plt.xticks(rotation = 'vertical')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df = pd.read_csv("/Users/jordanpagkalinawan/Desktop/NBA DV PROJECT/LAKER LEADERS/201617LakersRoster.csv")
playerName = df[df.Player == 'Player']
pointsPerGame = df[df.PTS == 'PTS']
reboundsPerGame = df[df.REB == 'REB']
assistsPerGame = df[df.AST == 'AST']
stealsPerGame = df[df.STL == 'STL']
blocksPerGame = df[df.BLK == 'BLK']
turnoversPerGame = df[df.TOV == 'TOV']
plt.title("2016-17 Lakers Turnovers Per Game")
plt.bar(df.Player, df.TOV)
plt.xticks(rotation = 'vertical')
plt.show()
